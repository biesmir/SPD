# %%
from schedule import Schedule
from simulated_annealing import *
import matplotlib.pyplot as plt
# %matplotlib inline
schdl = Schedule()
schdl.load_from_file("ta4")

steps = annealing(schdl, iterations=500)

plt.plot(steps)
plt.ylabel('some numbers')
plt.show()
